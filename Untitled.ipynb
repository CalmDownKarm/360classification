# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# %matplotlib inline
from sklearn.cluster import AgglomerativeClustering
from sklearn.neighbors import kneighbors_graph
from sklearn.manifold import TSNE
import gensim

# %%
# FastText Vectors
from fastText import tokenize, load_model
model = load_model("./wiki.en.bin")
df1 = pd.read_csv("./grantnav-20180526072920.csv",encoding='utf-8')

# %% [markdown]
# Titles aren't that useful, a lot of them are garbled.

# %%
# titles = [title for title in df.Title.unique() if isinstance(title,str)]
import re
# Cleaning Text
descs = [desc.encode('ascii',errors='ignore').decode('utf-8') for desc in df.Description.unique() if isinstance(desc,str)]
# Strip all hex 
desc_string = ' '.join(descs)
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
desc_tokens = tokenize(desc_string)
desc_tokens = [word.lower() for word in desc_tokens if (word.isalpha() and word.lower() not in stop_words)]

# %%
desc_tokens = list(set(desc_tokens))

# %%
# Word2Vec
model = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin.gz', binary=True)
vectors = [model[token] for token in desc_tokens]

# %%
# title_bow = list(set([word.lower() for word in tokenize(' '.join(titles)) if len(word)>1]))
desc_bow = list(set([word.lower() for word in tokenize(' '.join(descs)) if len(word)>1]))

# %%
# Title_bow_vectors = [model.get_word_vector(word) for word in title_bow]
Desc_bow_vectors = [model.get_word_vector(word) for word in desc_tokens]

# %%
clusterer = KMeans(n_clusters=100, n_init=10)

# %%
clusterer.fit(Desc_bow_vectors)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=100, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
df = pd.DataFrame(list(zip(desc_tokens, Desc_bow_vectors,clusterer.labels_)),columns = ['word', 'vector','label'])

# %%
df.groupby('label').count()
# Out:
#        word  vector
# label
# 0       593     593
# 1       371     371
# 2       542     542
# 3       261     261
# 4       508     508
# 5       408     408
# 6       910     910
# 7       619     619
# 8       882     882
# 9       787     787
# 10      516     516
# 11      524     524
# 12      426     426
# 13      522     522
# 14     1186    1186
# 15     1240    1240
# 16      647     647
# 17      976     976
# 18     1127    1127
# 19     1847    1847
# 20      505     505
# 21      534     534
# 22      411     411
# 23      659     659
# 24     1598    1598
# 25      355     355
# 26      751     751
# 27      537     537
# 28     1162    1162
# 29      877     877
# ...     ...     ...
# 70      815     815
# 71     1544    1544
# 72      877     877
# 73     1350    1350
# 74      729     729
# 75      407     407
# 76      515     515
# 77      720     720
# 78      458     458
# 79     1297    1297
# 80      545     545
# 81      291     291
# 82      498     498
# 83      456     456
# 84      459     459
# 85      463     463
# 86      366     366
# 87     2338    2338
# 88      529     529
# 89      596     596
# 90      442     442
# 91      801     801
# 92      840     840
# 93      353     353
# 94      666     666
# 95      464     464
# 96      732     732
# 97      415     415
# 98      709     709
# 99      363     363
#
# [100 rows x 2 columns]

# %%
cleaned_descs = []
for desc in descs:
    desc_tokens = tokenize(desc)
    cleaned_descs.append([word.lower() for word in desc_tokens if (word.isalpha() and word.lower() not in stop_words)])
    
# At this point I have a list of lists, where each list has the non stop words of that description. 
no_features = 100
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
tfidf = tfidf_vectorizer.fit_transform(df.lyrics)
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
nmf = NMF(n_components=no_topics, random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd').fit(tfidf)

# %% [markdown]
# ### Now I want to -
# 1. Find most important bwords in each description (TF-IDF?)
# 2. For each important word, see how many clusters it belongs to. thus build a m rows x 100 vectors

# %%
connectivity = kneighbors_graph(Desc_bow_vectors, n_neighbors=10, include_self=False)
ward = AgglomerativeClustering(n_clusters=15, connectivity=connectivity,linkage='ward').fit(Desc_bow_vectors)
# http://aa.ssdi.di.fct.unl.pt/files/AA-19_notes.pdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4477f8ae8d01> in <module>()
# ----> 1 connectivity = kneighbors_graph(Desc_bow_vectors, n_neighbors=10, include_self=False)
#       2 ward = AgglomerativeClustering(n_clusters=15, connectivity=connectivity,linkage='ward').fit(Desc_bow_vectors)
#       3 # http://aa.ssdi.di.fct.unl.pt/files/AA-19_notes.pdf
#
# NameError: name 'kneighbors_graph' is not defined
